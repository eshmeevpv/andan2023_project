# %%
import pandas as pd

# %%
excel_data = pd.read_excel('D:\Twich1.xlsx')

# %%
df = pd.concat(pd.read_excel('D:\Twich1.xlsx', sheet_name= None ), ignore_index= True ) # Объединяем все листки из Exel
df
# Out:
#         Unnamed: 0                              Game Watch time (hours)  \
# 0                0                 League of Legends      1,035,469,850
# 1                1  Counter-Strike: Global Offensive        526,391,918
# 2                2                            Dota 2        496,585,969
# 3                3                       Hearthstone        474,016,816
# 4                4                         Overwatch        178,958,678
# ...            ...                               ...                ...
# 277745       42395           Alien Covenant In Utero                 95
# 277746       42396                              Pivo                 95
# 277747       42397                          EbonSide                 95
# 277748       42398     The Consequences of Gardening                 95
# 277749       42399  Lucky Tlhalerwa: Super Incursion                 95
#
#        Stream time (hours) Peak viewers Peak channels Streamers  \
# ...

# %%
df_inf = df[['Game', 'Watch time (hours)', 'Streamers', 'Average channels']] # Выбрали нужные столбцы
df_inf
# Out:
#                                     Game Watch time (hours) Streamers  \
# 0                      League of Legends      1,035,469,850   625,380
# 1       Counter-Strike: Global Offensive        526,391,918   572,379
# 2                                 Dota 2        496,585,969   188,569
# 3                            Hearthstone        474,016,816   196,072
# 4                              Overwatch        178,958,678   564,462
# ...                                  ...                ...       ...
# 277745           Alien Covenant In Utero                 95         5
# 277746                              Pivo                 95         5
# 277747                          EbonSide                 95         8
# 277748     The Consequences of Gardening                 95         4
# 277749  Lucky Tlhalerwa: Super Incursion                 95        10
#
#        Average channels
# 0                 1,600
# 1                   890
# 2                   438
# 3                   267
# ...

# %%
Columns_inf= list(df_inf.columns.values[1:] )
Columns_inf
# Out:
# ['Watch time (hours)', 'Streamers', 'Average channels']

# %%
# Приводим тип данных к численным
for Columns in Columns_inf:
    df_inf[Columns] = df_inf[Columns].str.split(',').str.join('')
    df_inf[Columns] = pd.to_numeric(df_inf[Columns])
# Out:
# C:\Users\Иван\AppData\Local\Temp\ipykernel_11204\713942710.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_inf[Columns] = df_inf[Columns].str.split(',').str.join('')
# C:\Users\Иван\AppData\Local\Temp\ipykernel_11204\713942710.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_inf[Columns] = pd.to_numeric(df_inf[Columns])

# %%
df_inf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 277750 entries, 0 to 277749
# Data columns (total 4 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Game                277749 non-null  object
#  1   Watch time (hours)  277750 non-null  int64
#  2   Streamers           277750 non-null  int64
#  3   Average channels    277750 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 8.5+ MB

# %%
df_group = df_group.groupby(['Game']).mean()
df_group
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df_group = df_group.groupby(['Game']).mean()
#       2 df_group
#
# NameError: name 'df_group' is not defined

# %%
df_group.to_csv('Twich_sort.csv', sep=',')
